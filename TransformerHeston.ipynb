# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0.1):
    x = layers.MultiHeadAttention(num_heads=num_heads, key_dim=head_size)(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x + inputs)

    x_ff = layers.Dense(ff_dim, activation="relu")(x)
    x_ff = layers.Dense(inputs.shape[-1])(x_ff)
    x = layers.Dropout(dropout)(x_ff)
    x = layers.LayerNormalization(epsilon=1e-6)(x + x_ff)

    return x

# %%
def build_transformer_model(input_dim, num_features, head_size=64, num_heads=4, ff_dim=128, num_layers=2):
    inputs = layers.Input(shape=(num_features,))
    x = layers.Reshape((num_features, 1))(inputs)
    x = layers.Dense(head_size)(x)
    for _ in range(num_layers):
        x = transformer_encoder(x, head_size, num_heads, ff_dim)

    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dense(64, activation="relu")(x)
    x = layers.Dense(32, activation="relu")(x)
    outputs = layers.Dense(1)(x)

    model = models.Model(inputs, outputs)
    model.compile(optimizer="adam", loss="mse", metrics=["mae"])
    return model

# %%
bs_data = pd.read_csv('bs_data.csv')
heston_data = pd.read_csv('heston_data.csv')

# %%
bs_data
# Out:
#                 S           K         T         r     sigma  call_price label
# 0      103.290045  131.063618  4.900907  0.017751  0.243331   16.197959    BS
# 1      116.845571  142.017038  2.893580  0.048187  0.128066    7.417800    BS
# 2      115.194631  134.749222  0.618206  0.013403  0.288611    4.327009    BS
# 3      102.594761  114.299103  0.529129  0.041435  0.102126    0.484932    BS
# 4      122.087767  113.057180  3.602775  0.046209  0.265625   37.269109    BS
# ...           ...         ...       ...       ...       ...         ...   ...
# 99995  108.563931  142.061595  0.411876  0.022435  0.254733    0.481456    BS
# 99996  114.069979  132.328663  2.560343  0.035611  0.136477    7.194904    BS
# 99997  130.560273  143.123941  4.155809  0.013016  0.128519   11.498734    BS
# 99998  143.854490  129.150101  4.961218  0.049675  0.237826   52.341303    BS
# 99999  146.551936  127.243808  2.008501  0.017198  0.230951   31.767690    BS
#
# [100000 rows x 7 columns]

# %%
heston_data
# Out:
#                S           K         T         r        v0     kappa  \
# 0     148.500502  104.156266  2.422762  0.025632  0.368491  1.988959
# 1     101.297864  111.069185  4.098943  0.048740  0.556398  2.712698
# 2     100.284963  115.888022  1.836936  0.017240  0.075874  2.249124
# 3     120.546894  143.081810  4.020003  0.035742  0.553918  1.947384
# 4     141.838154  132.778985  1.350122  0.034980  0.364070  1.587303
# ...          ...         ...       ...       ...       ...       ...
# 9995  135.149676  139.615122  3.737802  0.039070  0.218526  1.952818
# 9996  118.044882  109.668124  1.101928  0.025664  0.341593  1.140302
# 9997  131.922220  131.450426  3.998019  0.032201  0.503926  2.306932
# 9998  101.884798  122.216351  4.435285  0.046327  0.528330  1.449800
# 9999  133.048864  105.429135  0.867920  0.042083  0.435209  2.187139
#
#          theta   sigma_v       rho  call_price   label
# 0     0.020955  0.368984 -0.472906   30.727535  Heston
# 1     0.014379  0.367446 -0.701654    3.155828  Heston
# 2     0.143667  0.101259 -0.594497   11.604038  Heston
# 3     0.114136  0.147010 -0.410906   27.651690  Heston
# 4     0.060344  0.129199 -0.875794   29.472240  Heston
# ...        ...       ...       ...         ...     ...
# 9995  0.146864  0.186053 -0.831234   23.652326  Heston
# 9996  0.047689  0.260040 -0.763109   19.321961  Heston
# 9997  0.020323  0.314564 -0.361633   16.983123  Heston
# 9998  0.083438  0.183676 -0.576949   17.649743  Heston
# 9999  0.042508  0.377560 -0.568697   28.258929  Heston
#
# [10000 rows x 11 columns]

# %%
bs_data['v0'] = bs_data['sigma']**2
bs_data['kappa'] = 0
bs_data['sigma_v'] = 0
bs_data['theta'] = bs_data['sigma']**2
bs_data['rho'] = 0

# %%
bs_data = bs_data.drop('sigma',axis=1)
bs_data.describe()
# Out:
#                    S              K              T              r  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean      125.071770     124.964082       2.554814       0.029955
# std        14.433018      14.481650       1.412534       0.011559
# min       100.000035     100.000001       0.100084       0.010001
# 25%       112.579170     112.418628       1.333705       0.019916
# 50%       125.155012     125.009313       2.558204       0.029944
# 75%       137.495288     137.480917       3.778421       0.039964
# max       149.999858     149.999727       4.999951       0.050000
#
#          call_price             v0     kappa   sigma_v          theta  \
# count  1.000000e+05  100000.000000  100000.0  100000.0  100000.000000
# mean   2.187218e+01       0.043373       0.0       0.0       0.043373
# std    1.424598e+01       0.023290       0.0       0.0       0.023290
# min    2.954185e-21       0.010000       0.0       0.0       0.010000
# 25%    1.043561e+01       0.022540       0.0       0.0       0.022540
# 50%    2.022842e+01       0.040056       0.0       0.0       0.040056
# 75%    3.164709e+01       0.062584       0.0       0.0       0.062584
# max    7.358491e+01       0.089997       0.0       0.0       0.089997
#
#             rho
# count  100000.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0

# %%
heston_data.describe()
# Out:
#                   S             K             T             r            v0  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean     125.023931    125.332141      2.579915      0.030007      0.304912
# std       14.366108     14.370888      1.421903      0.011568      0.171094
# min      100.004312    100.008138      0.100017      0.010007      0.010009
# 25%      112.629086    113.130196      1.363125      0.019942      0.155672
# 50%      125.065789    125.421975      2.597391      0.030078      0.307759
# 75%      137.500641    137.808829      3.818971      0.039985      0.451321
# max      149.998319    149.995052      4.999775      0.049999      0.599980
#
#               kappa         theta       sigma_v           rho    call_price
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       1.996561      0.104846      0.300635     -0.600829     17.289618
# std        0.575568      0.054932      0.114474      0.172167     11.198425
# min        1.000120      0.010022      0.100074     -0.899984      0.000000
# 25%        1.498080      0.057987      0.201909     -0.748841      8.431136
# 50%        2.001616      0.104193      0.301057     -0.604221     15.606057
# 75%        2.495222      0.152509      0.399068     -0.452352     24.533980
# max        2.999935      0.199971      0.499958     -0.300093     61.269368

# %%
features = ['S', 'K', 'T', 'r', 'v0', 'kappa', 'sigma_v', 'theta', 'rho']

# %%
X_bs = bs_data[features]
y_bs = bs_data['call_price']
X_heston = heston_data[features]
y_heston = heston_data['call_price']
y_bs = y_bs.to_numpy().reshape(-1, 1)
y_heston = y_heston.to_numpy().reshape(-1, 1)

# %%
scaler = StandardScaler()
X_bs_scaled = scaler.fit_transform(X_bs)
X_heston_scaled = scaler.fit_transform(X_heston)
scaler_y = StandardScaler()
y_bs_scaled = scaler_y.fit_transform(y_bs).flatten()
y_heston_scaled = scaler_y.fit_transform(y_heston).flatten()

# %%
X_bs_train, X_bs_test, y_bs_train, y_bs_test = train_test_split(X_bs_scaled, y_bs_scaled, test_size=0.2, random_state=42)
X_heston_train, X_heston_test, y_heston_train, y_heston_test = train_test_split(X_heston_scaled, y_heston_scaled, test_size=0.2, random_state=42)

# %%
model = build_transformer_model(input_dim=X_bs_train.shape[1], num_features=X_bs_train.shape[1])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 9)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 9, 1)      │          0 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 9, 64)     │        128 │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 9, 64)     │     66,368 │ dense_8[0][0],    │
# │ (MultiHeadAttentio… │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 9, 64)     │          0 │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 9, 64)     │          0 │ dropout_7[0][0],  │
# │                     │                   │            │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 9, 64)     │        128 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 9, 128)    │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 9, 64)     │      8,256 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 9, 64)     │          0 │ dense_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 9, 64)     │          0 │ dropout_8[0][0],  │
# │                     │                   │            │ dense_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 9, 64)     │        128 │ add_5[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 9, 64)     │     66,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 9, 64)     │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 9, 64)     │          0 │ dropout_10[0][0], │
# │                     │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 9, 64)     │        128 │ add_6[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 9, 128)    │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 9, 64)     │      8,256 │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 9, 64)     │          0 │ dense_12[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 9, 64)     │          0 │ dropout_11[0][0], │
# │                     │                   │            │ dense_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 9, 64)     │        128 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 64)        │      4,160 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 32)        │      2,080 │ dense_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 1)         │         33 │ dense_14[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 172,801 (675.00 KB)
#  Trainable params: 172,801 (675.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(
    X_bs_train, y_bs_train,
    validation_data=(X_bs_test, y_bs_test),
    epochs=50,
    batch_size=512,
)
# Out:
# Epoch 1/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 25s 72ms/step - loss: 0.9316 - mae: 0.7829 - val_loss: 0.8378 - val_mae: 0.7483
# Epoch 2/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.8105 - mae: 0.7377 - val_loss: 0.8211 - val_mae: 0.7340
# Epoch 3/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 0.8191 - mae: 0.7413 - val_loss: 0.8148 - val_mae: 0.7447
# Epoch 4/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.8168 - mae: 0.7401 - val_loss: 0.8109 - val_mae: 0.7341
# Epoch 5/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.8134 - mae: 0.7374 - val_loss: 0.8128 - val_mae: 0.7422
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.8179 - mae: 0.7411 - val_loss: 0.8150 - val_mae: 0.7294
# Epoch 7/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.8143 - mae: 0.7378 - val_loss: 0.8106 - val_mae: 0.7331
# Epoch 8/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.8158 - mae: 0.7403 - val_loss: 0.8123 - val_mae: 0.7377
# Epoch 9/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.8173 - mae: 0.7398 - val_loss: 0.8096 - val_mae: 0.7354
# Epoch 10/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.8201 - mae: 0.7401 - val_loss: 0.8105 - val_mae: 0.7380
# Epoch 11/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.8128 - mae: 0.7377 - val_loss: 0.8104 - val_mae: 0.7378
# Epoch 12/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.8191 - mae: 0.7405 - val_loss: 0.8109 - val_mae: 0.7370
# Epoch 13/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.8129 - mae: 0.7372 - val_loss: 0.8135 - val_mae: 0.7302
# Epoch 14/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.8141 - mae: 0.7370 - val_loss: 0.8103 - val_mae: 0.7378
# Epoch 15/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.8147 - mae: 0.7390 - val_loss: 0.8094 - val_mae: 0.7331
# Epoch 16/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.8144 - mae: 0.7364 - val_loss: 0.8104 - val_mae: 0.7312
# Epoch 17/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.8127 - mae: 0.7377 - val_loss: 0.8100 - val_mae: 0.7356
# Epoch 18/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.8121 - mae: 0.7377 - val_loss: 0.8115 - val_mae: 0.7401
# Epoch 19/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.8132 - mae: 0.7386 - val_loss: 0.8141 - val_mae: 0.7300
# Epoch 20/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8145 - mae: 0.7382 - val_loss: 0.8121 - val_mae: 0.7411
# Epoch 21/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.8088 - mae: 0.7358 - val_loss: 0.8126 - val_mae: 0.7418
# Epoch 22/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.8220 - mae: 0.7430 - val_loss: 0.8088 - val_mae: 0.7344
# Epoch 23/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.8094 - mae: 0.7345 - val_loss: 0.8107 - val_mae: 0.7403
# Epoch 24/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.8159 - mae: 0.7399 - val_loss: 0.8120 - val_mae: 0.7385
# Epoch 25/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.8104 - mae: 0.7363 - val_loss: 0.8087 - val_mae: 0.7350
# Epoch 26/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.8085 - mae: 0.7353 - val_loss: 0.8120 - val_mae: 0.7387
# Epoch 27/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.8102 - mae: 0.7359 - val_loss: 0.8141 - val_mae: 0.7364
# Epoch 28/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.8101 - mae: 0.7374 - val_loss: 0.8086 - val_mae: 0.7353
# Epoch 29/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.8089 - mae: 0.7349 - val_loss: 0.8086 - val_mae: 0.7357
# Epoch 30/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8140 - mae: 0.7377 - val_loss: 0.8125 - val_mae: 0.7342
# Epoch 31/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8181 - mae: 0.7404 - val_loss: 0.8076 - val_mae: 0.7362
# Epoch 32/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.8171 - mae: 0.7389 - val_loss: 0.8079 - val_mae: 0.7331
# Epoch 33/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.8117 - mae: 0.7377 - val_loss: 0.8088 - val_mae: 0.7335
# Epoch 34/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.8063 - mae: 0.7329 - val_loss: 0.8085 - val_mae: 0.7346
# Epoch 35/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8035 - mae: 0.7319 - val_loss: 0.8102 - val_mae: 0.7401
# Epoch 36/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.8087 - mae: 0.7360 - val_loss: 0.8111 - val_mae: 0.7345
# Epoch 37/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.8133 - mae: 0.7372 - val_loss: 0.8082 - val_mae: 0.7357
# Epoch 38/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8044 - mae: 0.7334 - val_loss: 0.8076 - val_mae: 0.7336
# Epoch 39/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.8097 - mae: 0.7359 - val_loss: 0.8085 - val_mae: 0.7339
# Epoch 40/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.8149 - mae: 0.7385 - val_loss: 0.8113 - val_mae: 0.7298
# Epoch 41/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.8101 - mae: 0.7350 - val_loss: 0.8095 - val_mae: 0.7356
# Epoch 42/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.8117 - mae: 0.7365 - val_loss: 0.8188 - val_mae: 0.7442
# Epoch 43/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.8139 - mae: 0.7379 - val_loss: 0.8097 - val_mae: 0.7324
# Epoch 44/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.8107 - mae: 0.7384 - val_loss: 0.8089 - val_mae: 0.7337
# Epoch 45/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.8147 - mae: 0.7376 - val_loss: 0.8091 - val_mae: 0.7370
# Epoch 46/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.8088 - mae: 0.7350 - val_loss: 0.8090 - val_mae: 0.7381
# Epoch 47/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8137 - mae: 0.7383 - val_loss: 0.8109 - val_mae: 0.7398
# Epoch 48/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.8168 - mae: 0.7385 - val_loss: 0.8097 - val_mae: 0.7329
# Epoch 49/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.8050 - mae: 0.7339 - val_loss: 0.8128 - val_mae: 0.7423
# Epoch 50/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.8069 - mae: 0.7350 - val_loss: 0.8094 - val_mae: 0.7379

# %%
model.fit(X_heston_train, y_heston_train,
          epochs=25,
          batch_size=128,
          validation_data=(X_heston_test, y_heston_test),
)
# Out:
# Epoch 1/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 140ms/step - loss: 0.9932 - mae: 0.8115 - val_loss: 0.9189 - val_mae: 0.7874
# Epoch 2/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.9663 - mae: 0.7981 - val_loss: 0.9186 - val_mae: 0.7863
# Epoch 3/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9263 - mae: 0.7805 - val_loss: 0.9163 - val_mae: 0.7822
# Epoch 4/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9514 - mae: 0.7883 - val_loss: 0.9183 - val_mae: 0.7872
# Epoch 5/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9630 - mae: 0.8001 - val_loss: 0.9121 - val_mae: 0.7819
# Epoch 6/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9657 - mae: 0.7966 - val_loss: 0.9128 - val_mae: 0.7820
# Epoch 7/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9683 - mae: 0.8022 - val_loss: 0.9199 - val_mae: 0.7895
# Epoch 8/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9620 - mae: 0.7978 - val_loss: 0.9177 - val_mae: 0.7886
# Epoch 9/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9375 - mae: 0.7871 - val_loss: 0.9144 - val_mae: 0.7874
# Epoch 10/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.9778 - mae: 0.8056 - val_loss: 0.9209 - val_mae: 0.7831
# Epoch 11/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9712 - mae: 0.8015 - val_loss: 0.9085 - val_mae: 0.7808
# Epoch 12/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9597 - mae: 0.7989 - val_loss: 0.9136 - val_mae: 0.7824
# Epoch 13/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0000 - mae: 0.8125 - val_loss: 0.9140 - val_mae: 0.7819
# Epoch 14/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9911 - mae: 0.8166 - val_loss: 0.9129 - val_mae: 0.7817
# Epoch 15/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9576 - mae: 0.7958 - val_loss: 0.9125 - val_mae: 0.7816
# Epoch 16/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9830 - mae: 0.8067 - val_loss: 0.9121 - val_mae: 0.7809
# Epoch 17/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.9495 - mae: 0.7927 - val_loss: 0.9090 - val_mae: 0.7798
# Epoch 18/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9614 - mae: 0.7987 - val_loss: 0.9137 - val_mae: 0.7862
# Epoch 19/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9870 - mae: 0.8111 - val_loss: 0.9131 - val_mae: 0.7807
# Epoch 20/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9698 - mae: 0.8014 - val_loss: 0.9117 - val_mae: 0.7832
# Epoch 21/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0031 - mae: 0.8157 - val_loss: 0.9134 - val_mae: 0.7824
# Epoch 22/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9618 - mae: 0.7966 - val_loss: 0.9151 - val_mae: 0.7806
# Epoch 23/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9594 - mae: 0.7946 - val_loss: 0.9144 - val_mae: 0.7860
# Epoch 24/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9420 - mae: 0.7916 - val_loss: 0.9116 - val_mae: 0.7830
# Epoch 25/25
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.9691 - mae: 0.8034 - val_loss: 0.9149 - val_mae: 0.7816

# %%
y_pred_scaled = model.predict(X_heston_test)
y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()
y_heston_test_inv = scaler_y.inverse_transform(y_heston_test.reshape(-1, 1)).flatten()
y_pred, y_heston_test_inv
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
# (array([16.349821, 19.156431, 15.486967, ..., 16.69319 , 19.145174,
#         15.294189], dtype=float32),
#  array([15.53726524, 34.37050267, 10.63214283, ...,  6.39319173,
#         16.00349019, 38.92628718]))

# %%
# Out:
# (2000, 2000)
